# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['figure.figsize'] = [10, 8] 
iris = sns.load_dataset('iris')

groups = iris.groupby('species')

fig, ax = plt.subplots()
for name, group in groups:
    ax.plot(group.petal_length, 
            group.petal_width, 
            marker='o', 
            linestyle='',
            label=name)

ax.legend(fontsize=12, loc='upper left') 
plt.title('Iris', fontsize=20)
plt.xlabel('Petal Length', fontsize=14)
plt.ylabel('Petal Width', fontsize=14)
plt.show()

# %%
fig2, ax2 = plt.subplots()
for name, group in groups:
    ax2.plot(group.sepal_length, 
            group.sepal_width, 
            marker='o', 
            linestyle='',
            label=name)

ax2.legend(fontsize=12, loc='upper left') 
plt.title('Iris', fontsize=20)
plt.xlabel('sepal_Length', fontsize=14)
plt.ylabel('sepal_width', fontsize=14)
plt.show()

# %%
fig3, ax3 = plt.subplots()
for name, group in groups:
    ax3.plot(group.sepal_length, 
            group.petal_width, 
            marker='o', 
            linestyle='',
            label=name)

ax3.legend(fontsize=12, loc='upper left') 
plt.title('Iris', fontsize=20)
plt.xlabel('sepal_Length', fontsize=14)
plt.ylabel('petal_width', fontsize=14)
plt.show()

# %%
fig3, ax3 = plt.subplots()
for name, group in groups:
    ax3.plot(group.sepal_length, 
            group.petal_width, 
            marker='o', 
            linestyle='',
            label=name)

ax3.legend(fontsize=12, loc='upper left') 
plt.title('Iris', fontsize=20)
plt.xlabel('sepal_Length', fontsize=14)
plt.ylabel('petal_width', fontsize=14)
plt.show()

# %%
fig3, ax3 = plt.subplots()
for name, group in groups:
    ax3.plot(group.sepal_width, 
            group.petal_length, 
            marker='o', 
            linestyle='',
            label=name)

ax3.legend(fontsize=12, loc='upper left') 
plt.title('Iris', fontsize=20)
plt.xlabel('sepal_width', fontsize=14)
plt.ylabel('petal_length', fontsize=14)
plt.show()

# %%
fig3, ax3 = plt.subplots()
for name, group in groups:
    ax3.plot(group.sepal_width, 
            group.petal_width, 
            marker='o', 
            linestyle='',
            label=name)

ax3.legend(fontsize=12, loc='upper left') 
plt.title('Iris', fontsize=20)
plt.xlabel('sepal_width', fontsize=14)
plt.ylabel('petal_width', fontsize=14)
plt.show()
